# %% [markdown]
# - AWS Batch - Managed batch processing service for data ingestion pipelines
#
# - AWS Lambda - Serverless compute to run code without managing servers
#
# - AWS Step Functions - Service to coordinate components in data workflows
#
# - AWS Glue - Serverless ETL tool to transform and catalog S3 data
#
# - Amazon EMR - Hosts frameworks like Spark and Hadoop for distributed data processing
#
# - Amazon Kinesis - Platform to ingest, process, and analyze streaming data
#
# - AWS Lambda - Serverless compute to run code without managing servers

# %% [markdown]
# #### Sagemaker Core: Git
# https://github.com/aws/amazon-sagemaker-examples/blob/default/%20%20%20%20%20%20%20%20%20sagemaker-core/get_started.ipynb

# %% [markdown]
# #### AWS Batch and Stream Processing
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Data Ingestion and Pipelines
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Transforming Data in Transit
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Handle Map Reduce for machine learning
# ![image.png](attachment:image.png)

# %% [markdown]
# #### EMR and Spark
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Check out how to deploy a hugging face pre-trained model to Amazon SageMaker:
# https://studiolab.sagemaker.aws/import/github/aws/studio-lab-examples/blob/main/connect-to-aws/Access_AWS_from_Studio_Lab_Deployment.ipynb

# %% [markdown]
# ## Deploy ML model Image on aws and deploy it using app runner. see below
#
# https://github.com/nogibjj/pytorch-fastapi-aws-apprunner/blob/main/README.md
